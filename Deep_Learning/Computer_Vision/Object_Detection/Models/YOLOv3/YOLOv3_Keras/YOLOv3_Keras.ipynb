# %% [markdown]
# <a href="https://colab.research.google.com/github/suresh-venkate/Code_Repositories/blob/main/Deep_Learning/Computer_Vision/Object_Detection/YOLOv3/YOLOv3_Keras/YOLOv3_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# # Complete setups and other preliminaries

# %% [markdown]
# ## Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Complete all installations and copy required files

# %%
# Uninstall current versions of Keras and TensorFlow
# !pip uninstall keras
# !pip uninstall tensorflow

# %%
# Install older versions of TensorFlow and Keras
# !pip install tensorflow==1.13.1
# !pip install keras==2.1.5

# %%
import tensorflow
import keras

# %%
print(tensorflow.__version__)
print(keras.__version__)
# Out:
# 1.13.1
# 2.1.5

# %%
# Clone keras-yolo3 repository from GitHub
# !git clone https://github.com/qqwweee/keras-yolo3.git
# Out:
# Cloning into 'keras-yolo3'...
# remote: Enumerating objects: 144, done.
# remote: Total 144 (delta 0), reused 0 (delta 0), pack-reused 144
# Receiving objects: 100% (144/144), 151.08 KiB | 1.62 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
# Download yolov3 pre-trained weights and create Keras model file
# %cd keras-yolo3/
# !wget https://pjreddie.com/media/files/yolov3.weights
# !python convert.py yolov3.cfg yolov3.weights model_data/yolo.h5
# Out:
# /content/keras-yolo3
# --2021-05-11 11:18:59--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  23.3MB/s    in 11s
#
# 2021-05-11 11:19:11 (21.6 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]
#
# Using TensorFlow backend.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# ...

# %%
# !wget https://raw.githubusercontent.com/suresh-venkate/Code_Repositories/main/Deep_Learning/Computer_Vision/Object_Detection/TF_Object_Detection_API/Pretrained_Model_Inference_Only/Images.zip
# !unzip Images.zip
# !rm Images.zip
# Out:
# --2021-05-11 11:20:56--  https://raw.githubusercontent.com/suresh-venkate/Code_Repositories/main/Deep_Learning/Computer_Vision/Object_Detection/TF_Object_Detection_API/Pretrained_Model_Inference_Only/Images.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 740805 (723K) [application/zip]
# Saving to: ‘Images.zip’
#
# Images.zip          100%[===================>] 723.44K  --.-KB/s    in 0.06s
#
# 2021-05-11 11:20:57 (12.4 MB/s) - ‘Images.zip’ saved [740805/740805]
#
# Archive:  Images.zip
#   inflating: Images/image1.jpg
#   inflating: Images/image2.jpg
#   inflating: Images/image3.jpg
#   inflating: Images/image4.jpg
#   inflating: Images/image5.jpg
#   inflating: Images/image6.jpg

# %%
# !python yolo_video.py --image --input Images/image1.jpg
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
